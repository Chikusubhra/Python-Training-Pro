# %% [markdown]
# # ***file handling***
# it is used to create,read,write & modify data inside the file with the help of prop lang

# %%
# open,read,write,close
"""
types of mode:
x=open('x')-create
r=readfile-read(),readline(),readlines()
w-write["hi","welcome"]
a=append
"""

# %%
# read file
"""f=open("file1.txt",'r')
data=f.read()
print(data)"""
# write file
"""f=open("file1.txt","w")
f.write("hello\n")
f.write("welcome to advance python class\n")
f.write("today we are gone read file handling")"""
# read(),readline(),readlines()
"""f=open("file1.txt","r")
print(f.read())
print(f.readline())
print(f.readlines())"""
"""f=open("file1.txt","r")
print(f.tell())
print(f.read())
print(f.tell())"""
# append
"""f=open("file1.txt","a")
f.write("\ni am teaching CSE students")
f.close()"""

# %%
# second file creating
"""
f=open("file2.txt","x")
"""
# write file
"""f=open("file2.txt","w")
f.write("hello this my second file")
f.write("hey what you doing")"""
# read file
"""f=open("file2.txt","r")
print(f.read())"""
# append
"""f=open("file2.txt","a")
f.write("\n hey what you doing")"""
# readline(),readlines()
"""f=open("file2.txt","r")
print(f.readline())
print(f.readlines())"""

# %%
# read file
"""f=open("file1.txt",'r')
data=f.read()
print(data)"""
# write file
"""f=open("file1.txt","w")
f.write("hello\n")
f.write("welcome to advance python class\n")
f.write("today we are gone read file handling")"""
# read(),readline(),readlines()
"""f=open("file1.txt","r")
print(f.read())
print(f.readline())
print(f.readlines())"""
"""f=open("file1.txt","r")
print(f.tell())
print(f.read())
print(f.tell())"""
# append
"""f=open("file1.txt","a")
f.write("\ni am teaching CSE students")
f.close()"""



# second file creating
"""
f=open("file2.txt","x")
"""
# write file
"""f=open("file2.txt","w")
f.write("hello this my second file")"""
# read file
"""f=open("file2.txt","r")
print(f.read())"""
# append
"""f=open("file2.txt","a")
f.write("\nhey what you doing")"""
# readline(),readlines()
"""f=open("file2.txt","r")
print(f.readline())
print(f.readlines())"""





# using "with"Keyword
"""with open("file2.txt") as f:
    print(f.read())"""

# file properties
"""f=open("file2.txt","a")
print(f.name)
print(f.mode)
print(f.closed)"""

# delete
"""f=open("file2.txt","r")
line=f.readlines()
del line[1]
f=open("file2.txt","w")
f.writelines(line)
f=open("file2.txt","r")
print(f.readlines())"""

# r+ -> read & write
"""f=open("file2.txt","r+")
print(f.tell())
print(f.read())
print(f.tell())
f.write("\nToday's topic is file handling")
print(f.read())
print(f.tell())"""

"""f=open("file1.txt","r+")
f.write("Good morning")
print(f.tell())
print(f.seek(0))
print(f.read())
f.close()"""

# w+ -> write & read
"""f=open("file1.txt","w+")
f.write("there is an override")
print(f.tell())
f.seek(0)
print(f.read())"""

# a+ -> write & read
"""f=open("file1.txt","a+")
f.write("\nhey there i'm chiku")
print(f.tell())
print(f.seek(0))
print(f.read())"""


# file2 operation

# r+ -> read & write
"""f=open("file2.txt","r+")
print(f.tell())
print(f.read())
print(f.tell())
f.write("\nToday's topic is file handling")
print(f.read())
print(f.tell())"""

"""f=open("file2.txt","r+")
f.write("Good morning")
print(f.tell())
print(f.seek(0))
print(f.read())
f.close()"""

# w+ -> write & read
"""f=open("file2.txt","w+")
f.write("there is an override")
print(f.tell())
f.seek(0)
print(f.read())"""

# a+ -> write & read
"""f=open("file2.txt","a+")
f.write("\nhey there i'm chiku")
print(f.tell())
print(f.seek(0))
print(f.read())"""


# file path
"""f=open('C:\\Users\\sk822\\Downloads\\new_file.txt',"w")
f.write("hi this is new file")

f=open("C:\\Users\\sk822\\Downloads\\new_file.txt","r")
print(f.read())"""

"""with open("C:\\Users\\sk822\\Downloads\\hi.txt","r+") as f:
    print(f.read())
    f.write("hi there everyone")
    print(f.tell())
    print(f.seek(0))
    print(f.readlines())"""

# binary file (image,rb,wb)
"""f=open("C:\\Users\\sk822\\OneDrive\\Pictures\\received_239034415707788.jpeg","rb")
f1=open("f1.jpg","wb")
for i in f:
    f1.write(i)"""

"""f=open("C:\\Users\\sk822\\OneDrive\\Pictures\\Camera Roll\\WIN_20260311_11_12_39_Pro.mp4","rb")
f1=open("mp4.mp4","wb")
for i in f:
    f1.write(i)"""
