# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr)
type(arr)
# Out:
# [1 2 3 4]
# numpy.ndarray

# %%
#arithmetic
a=5
b=5
add=a+b
sub=a-b
mul=a*b
div=a/b
modulo=a%b
exponent=a**b
floor=a//b
print(add)
print(sub)
print(mul)
print(div)
print(modulo)
print(exponent)
print(floor)
# Out:
# 10
# 0
# 25
# 1.0
# 0
# 3125
# 1

# %%
#assignment
a=5
a+=2
print(a)
a-=2
print(a)
a*=2
print(a)
a/=2
print(a)
# Out:
# 7
# 5
# 10
# 5.0

# %%
#bitwise
a=6
b=3
print(a&b)
print(a|b)
print(~b)
print(a^b)
print(a<<b)
print(a>>b)
# Out:
# 2
# 7
# -4
# 5
# 48
# 0
# 0

# %%
#comparison
a=5
b=3
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
print(a<b)
print(a>b)
# Out:
# False
# True
# True
# False
# False
# True

# %%
#identity
a=["apple","banana"]
b=["apple","banana"]
c=["apple","orange"]
print(a is not c)
print(a is b)
# Out:
# True
# False

# %%
#logical
x=5
print(x>0 and x<10)
print(x<5 or x>10)
print(not(x>3 and x<10))
# Out:
# True
# False
# False

# %%
#membership
fruits=["apple","banana","cherry"]
print("banana" in fruits)
# Out:
# True

# %%
#control statement
# if statement
a=5
if a==5:
  print("equal")
# Out:
# equal

# %%
# if elif
a=5
if a>5:
  print("equal")
else:
  print("not equal")
# Out:
# not equal

# %%
# if elif else
a=5
if a<5:
  print("less than 5")
elif(a>=5):
  print("greater or equal 5")
else:
  print("invalid")
# Out:
# greater or equal 5

# %%
# nested if
a=5
b=6
if a==b:
  print("equal")
elif(a>=b):
  print("greater or equal 5")
elif(a<=b):
  print("smaller or equal 5")
else:
  print("invalid")
# Out:
# smaller or equal 5

# %%
"""
mrks >90=a
>80=b
>70=c
>60=o
"""
mark=int(input("Enter the mark here: "))
if mark>90:
  print("grade a")
elif(mark>80 and mark<90):
  print("grade b")
elif(mark>70 and mark<80):
  print("grade c")
elif(mark>60 and mark<70):
  print("grade d")
else:
  print("fail")
# Out:
# Enter the mark here75
# grade c

# %%
# even odd
user=int(input("enter a number: "))
if user % 2==0:
  print("even number")
else:
  print("odd number")
# Out:
# enter a number: 54
# even number

# %%
# factorial of a number
num=int(input("enter a number: "))
fact=1
for i in range(1,num+1):
  fact=fact*i
print("factorial of the number ",num,"is: ",fact)
# Out:
# enter a number: 5
# factorial of the number  5 is:  120

# %%
# factorial in another process
def fact(num):
    if num <= 1:
        return 1
    else:
        return num * fact(num - 1)

print(fact(5))
# Out:
# 120

# %%
# prime number

def prime(number):
  for i in range(2,number):
    if num % i== 0:
      return False,"not prime"
  return True,"Prime"
number=int(input("enter a number: "))
prime(number)
# Out:
# enter a number: 3
# (True, 'Prime')

# %%
list1=[3,4,5,6]
mark=list1.copy()
print(mark)
print(sum(mark))
print(len(mark))
print(min(mark))
print(max(mark))
print(sorted(mark))
# Out:
# [3, 4, 5, 6]
# 18
# 4
# 3
# 6
# [3, 4, 5, 6]

# %%
lst = [12,34,56,78,90]
lst[-4:-1]
lst[::-1]
# Out:
# [90, 78, 56, 34, 12]

# %%
lis3=["hi","hlo","gm"]
lis3[-4:-1]
# Out:
# ['hi', 'hlo']

# %%
text="  Hey my name is sahil"

print(text.upper())
print(text.lower())
print(text.istitle())
print(text.title())
print(text.strip())
print(text.find("is"))
print(text.count("i"))
print(text.replace("name","self"))
print(text.split())

roll="23h"
print(roll.isdigit())

l=[10,20,30,40]
for i in l:
   if(i%2==0):
     print(i)
# Out:
#   HEY MY NAME IS SAHIL
#   hey my name is sahil
# False
#   Hey My Name Is Sahil
# Hey my name is sahil
# 14
# 2
#   Hey my self is sahil
# ['Hey', 'my', 'name', 'is', 'sahil']
# False
# 10
# 20
# 30
# 40

# %%
l=[10,20,30,40,71]
for i in l:
  if(i%2==0):
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
# TUPLE
tu=(1,2,3,4,3,78,988,101,1,4,45)
th=list(tu)
t1=("lucky","motu","abinash",89,23,30,"sahil")
t3=()
t4=(True,False)
t2=list(t1)
t2.append("bishu")
t2.reverse()
t5=tuple(t2)
print(tu)
print(t1)
print(t2)
print(len(t2))
print(t3)
print(t4)
print(t5)
print(type(t5))
print(sorted(th))
print(max(th))
print(min(th))
print(sum(th))
th.pop(1)
print(th)
th.clear()
print(th)
# Out:
# (1, 2, 3, 4, 3, 78, 988, 101, 1, 4, 45)
# ('lucky', 'motu', 'abinash', 89, 23, 30, 'sahil')
# ['bishu', 'sahil', 30, 23, 89, 'abinash', 'motu', 'lucky']
# 8
# ()
# (True, False)
# ('bishu', 'sahil', 30, 23, 89, 'abinash', 'motu', 'lucky')
# <class 'tuple'>
# [1, 1, 2, 3, 3, 4, 4, 45, 78, 101, 988]
# 988
# 1
# 1230
# [1, 3, 4, 3, 78, 988, 101, 1, 4, 45]
# []
