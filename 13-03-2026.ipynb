# %% [markdown]
# # ***Data comparison***

# %%
"""
reduce the file size
file compress-
file-size=10MB
reduce-7mb
fast sharing of file
1)lossless comp-.txt
->data remains as it is.
2)lossy comp-.txt
videos,img
->quality reduces
-binary files are lossy compress

in python
->zip->more that 1 file->ZipFile(),write()
->gzip->file(1-zip file)->rt,wt
->zlib->compress(),decompress()
binary
string
"""

# %%
# if it is not present then first cerate then write the sentence
w=open("file.txt","w")
w.write("hello")
# Out:
# 5

# %%
# zlib
"""
import zlib
str= b"This is advance python class."
compress_data=zlib.compress(str)
decompress_data=zlib.decompress(compress_data)
print("string after compression : ",compress_data)
print("string after decompression : ",decompress_data)
"""
# gzip
"""
import gzip
with gzip.open("Datafile.txt.gzip","wt") as f:
    f.write("hwllo students\n")
    f.write("Good Morning")

with gzip.open("Datafile.txt.gzip","rt") as f:
    print(f.read())
"""
# zipFile
"""
import zipfile

with zipfile.ZipFile("Python.zip","w") as f:
    f.write("file1.txt")
    f.write("file2.txt")

with zipfile.ZipFile("Python.zip","r") as f:
    print(f.namelist())     # o/p comes in a list

with zipfile.ZipFile("Python.zip","r") as f:
    f.extractall()

with zipfile.ZipFile("Python.zip","r") as f:
    f.extract("file2.txt")
"""
# practice
"""
import zipfile

with zipfile.ZipFile("Subhrajit.zip","w") as f:
    f.write("file1.txt")
    f.write("file2.txt")
    f.write("file3.txt")

with zipfile.ZipFile("Subhrajit.zip","r") as f:
    print(f.namelist())

with zipfile.ZipFile("subhrajit.zip","r") as f:
    f.extract("file1.txt")
"""


# list comprehension

# normal code
"""
l=[1,2,3,4,5]
empty_list=[]

for i in l:
    empty_list.append(i)
print(empty_list)
"""

# syntax:[expression, for variable_name in iteratable]
# list comprehension code
"""
l=[4,5,3,2,1]
emptylist=[i for i in l]
print(emptylist)
"""
# normal code
"""
l=[1,2,3,4,5]
square=[]
for i in l:
    square.append(i**2)
print(square)
"""

# list comprehenssion
"""
l=[1,2,3,4,5]
emptylist=[i**2 for i in l]
print(emptylist)
"""

# normal code

"""
l=[2,4,5,6,7]
even=[]
for i in l:
    if i%2==0:
        even.append(i)
print(even)
"""

# list comprehenssion

"""
l=[2,4,5,6,7]
even=[i for i in l if i%2==0]
print(even)
"""

# normal method
"""
l=["apple","banana","orange","kiwi"]
temp=[]
for i in l:
    temp.append(i.upper())
print(temp)
"""

# list comprehenssion

"""
l=["apple","banana","orange","kiwi"]
temp=[i.upper() for i in l]
print(temp)
"""

# normal code

"""
l=[1,2,3,4,5]
empty=[]
for i in l:
    if i%2==0:
        empty.append("even")
    else:
        empty.append("odd")
print(empty)
"""
